# %% [markdown]
# #AIRPLANE CRASHES AND FATALITIES (1908-2010)

# %% [markdown]
# LIBRARIES

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import random
import csv
import os

# %% [markdown]
# PULL DATA

# %%
data = pd.read_csv('https://query.data.world/s/hb5kpazt62cmskyambownsj76plhtd', index_col = 0, parse_dates = True)
data
# Out:
#              Time  ...                                            Summary
# Date               ...
# 1908-09-17  17:18  ...  During a demonstration flight, a U.S. Army fly...
# 1912-07-12   6:30  ...  First U.S. dirigible Akron exploded just offsh...
# 1913-08-06    NaN  ...  The first fatal airplane accident in Canada oc...
# 1913-09-09  18:30  ...  The airship flew into a thunderstorm and encou...
# 1913-10-17  10:30  ...  Hydrogen gas which was being vented was sucked...
# ...           ...  ...                                                ...
# 2009-05-20   6:30  ...  While on approach, the military transport cras...
# 2009-05-26    NaN  ...  The cargo plane crashed while on approach to I...
# 2009-06-01   0:15  ...  The Airbus went missing over the AtlantiOcean ...
# 2009-06-07   8:30  ...  The air ambulance crashed into hills while att...
# 2009-06-08    NaN  ...  The military transport went missing while en r...
#
# [5268 rows x 12 columns]

# %% [markdown]
# FATALITY, PER EACH RECORDED CRASH (1908-2009)

# %%
data.Fatalities.iloc[0:5268].plot(color = "red", marker = "o", linestyle = "-", figsize=(25,14))
plt.xlabel("DATE")
plt.ylabel("FATALITY PER CRASH")
data.Fatalities
# Out:
# Date
# 1908-09-17      1.0
# 1912-07-12      5.0
# 1913-08-06      1.0
# 1913-09-09     14.0
# 1913-10-17     30.0
#               ...
# 2009-05-20     98.0
# 2009-05-26      4.0
# 2009-06-01    228.0
# 2009-06-07      1.0
# 2009-06-08     13.0
# Name: Fatalities, Length: 5268, dtype: float64

# %% [markdown]
# CRASHES BETWEEN (1908-1950)

# %%
data[:1041]

# %% [markdown]
# CRASHES BETWEEN 1950-2010

# %%
data[1041:]

# %% [markdown]
# -------
# -------

# %% [markdown]
# SEE THE CRASHES BETWEEN THE YEARS THAT YOU HAVE CHOSEN
#
# ---

# %% [markdown]
# **1-> 1908-1920, 2-> 1920-1930, 3-> 1930-1940, 4-> 1940-1950, 5-> 1950-1960,
# 6-> 1960-1970, 7-> 1970-1980, 8-> 1980-1990, 9 ->1990-2000, 0-> 2000-2009 belirtilen sayıları tuşlamak, belirtilen yıllar arasındaki kazaları ve ölüm sayılarını gösterir...**

# %%
def yil():
  a = int(input("1908-1920 yillarini gorebilmek icin 1i tuslayin, 1920-1930 icin 2yi, 1930-1940 icin 3u, 1940-1950 icin 4u 1950-1960 icin 5i, 1960-1970 icin 6yi, 70-80 icin 7yi, 80-90 icin 8i, 90-00 icin 9u, 00-09 icin 0i tuslayin: "))
  if (a == 1):
    print(data[:28])
    data.Fatalities.iloc[:28].plot(color = "turquoise", marker = "*", linestyle = "--", figsize=(15,8))
  if (a == 2):
    print(data[28:206])
    data.Fatalities.iloc[28:206].plot(color = "red", marker = "*", linestyle = "--", figsize=(15,8))
  if (a == 3):
    print(data[206:531])
    data.Fatalities.iloc[206:531].plot(color = "cyan", marker = "o", linestyle = "-", figsize=(15,8))
  if (a == 4):
    print(data[531:1000])
    data.Fatalities.iloc[531:1000].plot(color = "violet", marker = "o", linestyle = "-", figsize=(15,8))
  if (a == 5):
    print(data[1001:1638])
    data.Fatalities.iloc[1001:1638].plot(color = "yellow", marker = "*", linestyle = "--", figsize=(15,8))
  if (a == 6):
    print(data[1638:2362])
    data.Fatalities.iloc[1638:2362].plot(color = "cadetblue", marker = "*", linestyle = "--", figsize=(15,8))
  if (a == 7):
    print(data[2362:3196])
    data.Fatalities.iloc[2362:3196].plot(color = "coral", marker = "o", linestyle = "-", figsize=(15,8))
  if (a == 8):
    print(data[3196:3912])
    data.Fatalities.iloc[3196:3912].plot(color = "pink", marker = "o", linestyle = "-", figsize=(15,8))
  if (a == 9):
    print(data[3912:4682])
    data.Fatalities.iloc[3912:4682].plot(color = "darkolivegreen", marker = "*", linestyle = "--", figsize=(15,8))
  if (a == 0):
    print(data[4682:5268])
    data.Fatalities.iloc[4682:5268].plot(color = "magenta", marker = "*", linestyle = "--", figsize=(15,8))

  return

yil()
# Out:
# 1908-1920 yillarini gorebilmek icin 1i tuslayin, 1920-1930 icin 2yi, 1930-1940 icin 3u, 1940-1950 icin 4u 1950-1960 icin 5i, 1960-1970 icin 6yi, 70-80 icin 7yi, 80-90 icin 8i, 90-00 icin 9u, 00-09 icin 0i tuslayin: 1
#              Time  ...                                            Summary
# Date               ...
# 1908-09-17  17:18  ...  During a demonstration flight, a U.S. Army fly...
# 1912-07-12   6:30  ...  First U.S. dirigible Akron exploded just offsh...
# 1913-08-06    NaN  ...  The first fatal airplane accident in Canada oc...
# 1913-09-09  18:30  ...  The airship flew into a thunderstorm and encou...
# 1913-10-17  10:30  ...  Hydrogen gas which was being vented was sucked...
# 1915-03-05   1:00  ...  Crashed into trees while attempting to land af...
# 1915-09-03  15:20  ...  Exploded and burned near Neuwerk Island,  when...
# 1916-07-28    NaN  ...         Crashed near the Black Sea, cause unknown.
# ...
